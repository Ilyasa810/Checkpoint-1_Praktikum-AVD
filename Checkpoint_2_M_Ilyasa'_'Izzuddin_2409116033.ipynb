# %% [markdown]
# ## **Checkpoint 2 - Data Understanding & Data Preparation**
#
# Nama: Muhammad Ilyasa' 'Izzuddin
#
# NIM: 2409116033
#
# Link dataset: https://www.kaggle.com/datasets/damirdizdarevic/uefa-euro-2024-players

# %%
import pandas as pd

# %%
file_path = "/content/euro2024_players.csv"

df = pd.read_csv(file_path)

# %%
df
# Out:
#                       Name        Position  Age                 Club  Height  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona     187
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich     193
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund     191
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen     195
# ..                     ...             ...  ...                  ...     ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague     187
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199
#
# ...

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# ### Menampilkan 5 baris pertama

# %%
print(df.head())
# Out:
#                     Name     Position  Age                 Club  Height  \
# 0  Marc-André ter Stegen   Goalkeeper   32         FC Barcelona     187
# 1           Manuel Neuer   Goalkeeper   38        Bayern Munich     193
# 2         Oliver Baumann   Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3     Nico Schlotterbeck  Centre-Back   24    Borussia Dortmund     191
# 4           Jonathan Tah  Centre-Back   28  Bayer 04 Leverkusen     195
#
#     Foot  Caps  Goals  MarketValue  Country
# 0  right    40      0     28000000  Germany
# 1  right   119      0      4000000  Germany
# 2  right     0      0      3000000  Germany
# 3   left    12      0     40000000  Germany
# 4  right    25      0     30000000  Germany

# %% [markdown]
# ### Menampilkan 5 baris terakhir

# %%
print(df.tail())
# Out:
#               Name        Position  Age                 Club  Height   Foot  \
# 618    Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188  right
# 619  Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191   left
# 620  Mojmír Chytil  Centre-Forward   25     SK Slavia Prague     187      -
# 621     Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185  right
# 622    Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199  right
#
#      Caps  Goals  MarketValue         Country
# 618    31      2     12000000  Czech Republic
# 619    37     18     22000000  Czech Republic
# 620    12      4      6500000  Czech Republic
# 621    20      3      5000000  Czech Republic
# 622     3      2      3200000  Czech Republic

# %% [markdown]
# ### Menampilkan ringkasan informasi dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         623 non-null    object
#  1   Position     623 non-null    object
#  2   Age          623 non-null    int64
#  3   Club         623 non-null    object
#  4   Height       623 non-null    int64
#  5   Foot         620 non-null    object
#  6   Caps         623 non-null    int64
#  7   Goals        623 non-null    int64
#  8   MarketValue  623 non-null    int64
#  9   Country      623 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 48.8+ KB
# None

# %% [markdown]
# ### Menampilkan tipe data setiap kolom

# %%
print(df.dtypes)
# Out:
# Name           object
# Position       object
# Age             int64
# Club           object
# Height          int64
# Foot           object
# Caps            int64
# Goals           int64
# MarketValue     int64
# Country        object
# dtype: object

# %% [markdown]
# ### Menampilkan jumlah baris dan kolom

# %%
print(df.shape)
# Out:
# (623, 10)

# %% [markdown]
# ### Menampilkan statistik deskriptif

# %%
print(df.describe())
# Out:
#               Age      Height        Caps       Goals   MarketValue
# count  623.000000  623.000000  623.000000  623.000000  6.230000e+02
# mean    27.040128  184.181380   30.338684    4.152488  1.840903e+07
# std      4.124275    6.569258   30.987902   10.086803  2.426195e+07
# min     16.000000  167.000000    0.000000    0.000000  5.000000e+04
# 25%     24.000000  180.000000    7.000000    0.000000  2.900000e+06
# 50%     27.000000  185.000000   21.000000    1.000000  9.000000e+06
# 75%     30.000000  189.000000   42.000000    4.000000  2.500000e+07
# max     41.000000  202.000000  206.000000  128.000000  1.800000e+08

# %% [markdown]
# ### Menghitung korelasi antar kolom numerik

# %%
print(df.corr(numeric_only=True))
# Out:
#                   Age    Height      Caps     Goals  MarketValue
# Age          1.000000  0.084409  0.642829  0.310144    -0.331067
# Height       0.084409  1.000000 -0.051479 -0.018785    -0.070983
# Caps         0.642829 -0.051479  1.000000  0.636180    -0.004987
# Goals        0.310144 -0.018785  0.636180  1.000000     0.107315
# MarketValue -0.331067 -0.070983 -0.004987  0.107315     1.000000

# %% [markdown]
# ## **Data Preparation**
#
# Link Dataset: https://www.kaggle.com/datasets/damirdizdarevic/uefa-euro-2024-players

# %%
df
# Out:
#                       Name        Position  Age                 Club  Height  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona     187
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich     193
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund     191
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen     195
# ..                     ...             ...  ...                  ...     ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague     187
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199
#
# ...

# %% [markdown]
# ### Melihat Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Name           0.000000
# Position       0.000000
# Age            0.000000
# Club           0.000000
# Height         0.000000
# Foot           0.481541
# Caps           0.000000
# Goals          0.000000
# MarketValue    0.000000
# Country        0.000000
# dtype: float64

# %%
df[df['Foot'].isnull()]
# Out:
#                   Name        Position  Age               Club  Height Foot  \
# 390  Maximilian Entrup  Centre-Forward   26       TSV Hartberg     186  NaN
# 418    Thomas Kaminski      Goalkeeper   31         Luton Town     190  NaN
# 472   Bogdan Racovițan     Centre-Back   24  Raków Częstochowa     187  NaN
#
#      Caps  Goals  MarketValue  Country
# 390     2      1      2000000  Austria
# 418     1      0      3000000  Belgium
# 472     2      0      1800000  Romania

# %%
df['Foot'].dropna().describe()
# Out:
# count       620
# unique        4
# top       right
# freq        436
# Name: Foot, dtype: object

# %%
df['Foot'] = df['Foot'].fillna(df['Foot'].dropna().mode()[0])

# %%
df
# Out:
#                       Name        Position  Age                 Club  Height  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona     187
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich     193
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund     191
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen     195
# ..                     ...             ...  ...                  ...     ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague     187
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199
#
# ...

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#              Null Ratio %
# Name                  0.0
# Position              0.0
# Age                   0.0
# Club                  0.0
# Height                0.0
# Foot                  0.0
# Caps                  0.0
# Goals                 0.0
# MarketValue           0.0
# Country               0.0

# %% [markdown]
# ### Melihat apakah ada kolom yang terduplikasi

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Position, Age, Club, Height, Foot, Caps, Goals, MarketValue, Country]
# Index: []

# %% [markdown]
# ### Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom        Persentase Outliers
# Age                     0.160514
# Height                  0.000000
# Caps                    4.975923
# Goals                  10.272873
# MarketValue             6.581059

# %%
df
# Out:
#                       Name        Position  Age                 Club  Height  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona     187
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich     193
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund     191
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen     195
# ..                     ...             ...  ...                  ...     ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague     187
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199
#
# ...

# %% [markdown]
# ## Construct Data

# %%
file_path = "/content/euro2024_players.csv"

df = pd.read_csv(file_path)

df["Rasio_Goals"] = df["Goals"] * df["Caps"]

# %%
df
# Out:
#                       Name        Position  Age                 Club  Height  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona     187
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich     193
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund     191
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen     195
# ..                     ...             ...  ...                  ...     ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague     187
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199
#
# ...

# %% [markdown]
# ## Data Reduction

# %%
df = df.drop('Height', axis=1)

# %%
df
# Out:
#                       Name        Position  Age                 Club   Foot  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona  right
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich  right
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim  right
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund   left
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen  right
# ..                     ...             ...  ...                  ...    ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen  right
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen   left
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague      -
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague  right
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen  right
#
# ...

# %% [markdown]
# ### Inconsistent Value

# %%
df
# Out:
#                       Name        Position  Age                 Club   Foot  \
# 0    Marc-André ter Stegen      Goalkeeper   32         FC Barcelona  right
# 1             Manuel Neuer      Goalkeeper   38        Bayern Munich  right
# 2           Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim  right
# 3       Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund   left
# 4             Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen  right
# ..                     ...             ...  ...                  ...    ...
# 618            Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen  right
# 619          Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen   left
# 620          Mojmír Chytil  Centre-Forward   25     SK Slavia Prague      -
# 621             Jan Kuchta  Centre-Forward   27     AC Sparta Prague  right
# 622            Tomas Chory  Centre-Forward   29    FC Viktoria Plzen  right
#
# ...

# %% [markdown]
# Dataset ini tidak memiliki inconsistent value
